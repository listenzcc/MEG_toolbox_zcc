# %%
# %% Importing
# System
import os
import sys

# Computing
import mne
import numpy as np

# Plotting
import matplotlib.pyplot as plt
from surfer import Brain
from mayavi import mlab

__file__ = os.path.curdir
sys.path.append(os.path.join(os.path.dirname(__file__), '..', 'tools'))  # noqa
from MEG_worker import MEG_Worker
from visualizer import Visualizer
from inverse_solver import Inverse_Solver

# %%
mne.utils.get_config()
# Out:
# {'MNE_COREG_ADVANCED_RENDERING': 'true',
#  'MNE_COREG_COPY_ANNOT': 'true',
#  'MNE_COREG_GUESS_MRI_SUBJECT': 'true',
#  'MNE_COREG_HEAD_HIGH_RES': 'true',
#  'MNE_COREG_HEAD_OPACITY': '1.0',
#  'MNE_COREG_INTERACTION': 'trackball',
#  'MNE_COREG_MARK_INSIDE': 'false',
#  'MNE_COREG_ORIENT_TO_SURFACE': 'false',
#  'MNE_COREG_PREPARE_BEM': 'true',
#  'MNE_COREG_PROJECT_EEG': 'false',
#  'MNE_COREG_SCALE_BY_DISTANCE': 'false',
#  'MNE_COREG_SCALE_LABELS': 'true',
#  'MNE_COREG_SCENE_SCALE': '0.16',
#  'MNE_COREG_WINDOW_HEIGHT': '600',
#  'MNE_COREG_WINDOW_WIDTH': '800',
#  'MNE_DATASETS_SAMPLE_PATH': '/home/zcc/mne_data',
#  'MNE_DATASETS_SPM_FACE_PATH': '/home/zcc/mne_data',
#  'MNE_USE_CUDA': 'true',
#  'SUBJECTS_DIR': '/home/zcc/Documents/freesurfer/subjects',
#  'SUBJECT_DIR': '/nfs/diskstation/zccdata/freesurfer/subjects'}

# %%
try:
    src_fsaverage = mne.read_source_spaces('fsaverage_src.fif')
except:
    src_fsaverage = mne.setup_source_space('fsaverage', spacing='oct6', n_jobs=40)
    mne.write_source_spaces('src_fsaverage_src.fif', src)
src_fsaverage
# Out:
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
# <SourceSpaces: [<surface (lh), n_vertices=163842, n_used=4098>, <surface (rh), n_vertices=163842, n_used=4098>] MRI (surface RAS) coords, subject 'fsaverage'>

# %%
# %%
# DO NOT RUN THIS UNLESS YOU WANT TO RECOMPUTE STC
stcs = dict()
stcs_baseline = dict()

spacing = [s['vertno'] for s in src_fsaverage]

for idx in range(1, 11):
    running_name = f'MEG_S{idx:02d}'
    band_name = 'U07'

    worker = MEG_Worker(running_name=running_name)
    worker.pipeline(band_name=band_name)

    # %%
    # epochs = worker.denoise_epochs['3']
    epochs = worker.clean_epochs
    epochs_baseline = worker.epochs['2']
    solver = Inverse_Solver(running_name=running_name)
    solver.pipeline(epochs=epochs,
                    raw_info=worker.raw.info)

    # %%
    stc, stc_fsaverage = solver.estimate(obj=epochs.average(), spacing=spacing)
    stc, stc_fsaverage_baseline = solver.estimate(obj=epochs_baseline.average(), spacing=spacing)
    
    stcs[running_name] = stc_fsaverage
    stcs_baseline[running_name] = stc_fsaverage_baseline
    
display(stcs)
display(stcs_baseline)

data = stc_fsaverage.data * 0
for running_name in stcs:
    data += stcs[running_name].data
stc_fsaverage.data = data / len(stcs)

data = stc_fsaverage_baseline.data * 0
for running_name in stcs_baseline:
    data += stcs_baseline[running_name].data
stc_fsaverage_baseline.data = data / len(stcs)

stc_fsaverage.save('stc_fsaverage')
stc_fsaverage_baseline.save('stc_fsaverage_baseline')
# Out:
# Found 8 files that ends with _ica-raw.fif
# >> Got <Raw | block_07_ica-raw.fif, 409 x 2952000 (2460.0 s), ~1017 kB, data not loaded> from ['/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_07_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_08_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_09_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_10_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_05_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_03_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_06_ica-raw.fif', '/home/zcc/RSVP_dataset/processed_data/MEG_S01/block_04_ica-raw.fif']
# Reading /home/zcc/RSVP_dataset/memory/MEG_S01-U07-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 3576 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# >> Raw epochs are recalled from memory: <EpochsFIF  |   3576 events (all good), -0.2 - 1.2 sec, baseline off, ~1.02 GB, data loaded,
#  '1': 448
#  '2': 2715
#  '3': 413>
# Reading /home/zcc/RSVP_dataset/memory/MEG_S01-U07-denoise-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 3576 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# >> Denoise epochs are recalled from memory: <EpochsFIF  |   3576 events (all good), -0.2 - 1.2 sec, baseline [-0.2, 0], ~1.02 GB, data loaded,
#  '1': 448
#  '2': 2715
#  '3': 413>
# Reading /home/zcc/RSVP_dataset/memory/MEG_S01-U07-clean-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 448 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# >> Clean epochs are recalled from memory: <EpochsFIF  |   448 events (all good), -0.2 - 1.2 sec, baseline [-0.2, 0], ~131.6 MB, data loaded,
#  '1': 448>
# Inversing on RSVP_MRI_S01
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S01/RSVP_MRI_S01-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S01-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S01-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 448
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.0% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S01, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# . in <module>
#      19
#      20     # %%
# ---> 21     stc, stc_fsaverage = solver.estimate(obj=epochs.average())
#      22     stc, stc_fsaverage_baseline = solver.estimate(obj=epochs_baseline.average())
#      23
#
# ~/Documents/zcc_meg_toolbox/tools/inverse_solver.py in estimate(self, obj, subject_to, spacing, lambda2)
#     150                                          subject_from=stc.subject,
#     151                                          subject_to=subject_to,
# --> 152                                          spacing=spacing)
#     153
#     154         # SourceEstimate in fsaverage space
#
# <decorator-gen-277> in compute_source_morph(src, subject_from, subject_to, subjects_dir, zooms, niter_affine, niter_sdr, spacing, smooth, warn, xhemi, sparse, src_to, verbose)
#
# ~/anaconda3/lib/python3.7/site-packages/mne/morph.py in compute_source_morph(***failed resolving arguments***)
#     225         else:
#     226             vertices_to = grade_to_vertices(
# --> 227                 subject_to, spacing, subjects_dir, 1)
#     228             morph_mat = _compute_morph_matrix(
#     229                 subject_from=subject_from, subject_to=subject_to,
#
# <decorator-gen-280> in grade_to_vertices(subject, grade, subjects_dir, n_jobs, verbose)
#
# ~/anaconda3/lib/python3.7/site-packages/mne/morph.py in grade_to_vertices(subject, grade, subjects_dir, n_jobs, verbose)
#     958         Vertex numbers for LH and RH.
#     959     """
# --> 960     _validate_type(grade, (list, 'int-like', None), 'grade')
#     961     # add special case for fsaverage for speed
#     962     if subject == 'fsaverage' and isinstance(grade, int) and grade == 5:
#
# ~/anaconda3/lib/python3.7/site-packages/mne/utils/check.py in _validate_type(item, types, item_name, type_name)
#     378                 type_name = ', '.join(type_name)
#     379         raise TypeError('%s must be an instance of %s, got %s instead'
# --> 380                         % (item_name, type_name, type(item),))
#     381
#     382
#
# TypeError: grade must be an instance of list, int-like, or None, got <class 'str'> instead

# %%
# %%
mne.viz.set_3d_backend('pyvista')

label_list_aparc = mne.read_labels_from_annot('fsaverage', 'aparc', 'both')
label_list_visuotopic = mne.read_labels_from_annot('fsaverage', 'PALS_B12_Visuotopic', 'both')

display(label_list_aparc)
display(label_list_visuotopic)

labels = dict()

for j, label in enumerate(label_list_visuotopic):
    if label.name.startswith('Visuotopic'):
        labels[label.name] = label
        
ROIs = ['fusiform',
        'temporal',
       ]
for j, label in enumerate(label_list_aparc):
    labels[label.name] = label

# %%
# DO NOT RUN THIS,
# IT IS VERY SLOW
if False:
    brain = Brain(subject_id='fsaverage',
                  hemi='split',
                  surf='inflated',
                  cortex='low_contrast',
                  background='white',
                  size=(800, 600))
    # brain.add_annotation('aparc')
    # brain.add_annotation(label_name)
    for name in labels:
        print(name)
        brain.add_label(labels[name], borders=True)
    print('Done.')

    mlab.show()

# %%
stc_fsaverage = mne.read_source_estimate('stc_fsaverage')
stc_fsaverage_baseline = mne.read_source_estimate('stc_fsaverage_baseline')

stc = stc_fsaverage_baseline
stc.data = stc_fsaverage.data - stc_fsaverage_baseline.data

# %%
alldata = sorted(stc.data.ravel(), reverse=True)
n = len(alldata)
LIMS = [alldata[int(n * r)] for r in [0.05, 0.01, 0.005, 0]]
LIMS

# %%
lims = LIMS[1:]

from sklearn.manifold import TSNE

data = stc.data
large_data = data[np.max(data, axis=1) > lims[0]]
large_data.shape, data.shape

tsne = TSNE(n_components=2, n_jobs=40)
proj_data = tsne.fit_transform(data.transpose())

plt.style.use('ggplot')
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

ax.scatter(proj_data[:, 0], proj_data[:, 1], range(141), alpha=0.5)
ax.plot(proj_data[:, 0], proj_data[:, 1])

idxs = []
for t in [0.0, 0.3, 0.5, 0.8]:
    idx = np.where(t == stc.times)[0][0]
    ax.text(proj_data[idx, 0]+0.2, proj_data[idx, 1]+0.2, t, fontdict=dict(size=15))
    idxs.append(idx)
    
ax.scatter(proj_data[idxs, 0], proj_data[idxs, 1], 100)
ax.set_title('TSNE')

fig.savefig('TSNE.png')

# %%
ts = mne.extract_label_time_course(stc, labels, src, mode='mean_flip', allow_empty=True, return_generator=True)

# %%
lims = LIMS[1:]

plt.style.use('ggplot')
fig, axes = plt.subplots(1, 2, figsize=(8, 10))

times = stc.times
select_labels = dict()
for name in labels:
    label = labels[name]
    color = label.color
    try:
        stc_inlabel = stc.in_label(label)
    except ValueError:
        continue
    data = stc_inlabel.data
    data = data[np.max(data, axis=1) > lims[0]]
    if len(data) < 100:
        continue
    # print(name, color, data.shape)
    
#     sort = sorted(data.ravel(), reverse=True)
#     if sort[1000] < lims[0]:
#         continue
    
    mean_data = np.mean(data, axis=0)
    
    if name.endswith('-lh'):
        ax = axes[0]
    else:
        ax = axes[1]
        
    ax.plot(times, mean_data, c=color, label=f'{name}-{len(data)}', alpha=0.5, linewidth=3)
    
    select_labels[name] = label

for j in [0, 1]:
    axes[j].legend(loc='upper left', bbox_to_anchor=(0, -0.1))
    
axes[0].set_title('LEFT')
axes[1].set_title('RIGHT')

fig.tight_layout()
fig.savefig('WaveForm.png')

# %%
help(stc.plot)

# %%
lims = LIMS[:3]
mne.viz.set_3d_backend('pyvista')
views = ['lat', 'med', 'cau', 'dor', 'ven']
clim = dict(kind='value', lims=lims)
surfer_kwargs = dict(hemi='both',
                     clim=clim,
                     views=views,
                     initial_time=0.5,
                     time_unit='s',
                     size=(800, 800),
                     smoothing_steps=10,
                     time_viewer=False,
                     subject='fsaverage')

# This can not be operated using VS code
brain = stc.plot(**surfer_kwargs)

for name in select_labels:
    print(name)
    brain.add_label(labels[name], borders=True)

# mlab.show()
