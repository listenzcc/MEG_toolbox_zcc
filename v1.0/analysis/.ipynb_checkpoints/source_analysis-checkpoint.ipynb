# %%
# %% Importing
# System
import os
import sys

# Computing
import mne
import numpy as np

# Plotting
import matplotlib.pyplot as plt
from surfer import Brain
from mayavi import mlab

__file__ = os.path.curdir
sys.path.append(os.path.join(os.path.dirname(__file__), '..', 'tools'))  # noqa
from MEG_worker import MEG_Worker
from visualizer import Visualizer
from inverse_solver import Inverse_Solver

# %%
mne.utils.get_config()
# Out:
# {'MNE_COREG_ADVANCED_RENDERING': 'true',
#  'MNE_COREG_COPY_ANNOT': 'true',
#  'MNE_COREG_GUESS_MRI_SUBJECT': 'false',
#  'MNE_COREG_HEAD_HIGH_RES': 'true',
#  'MNE_COREG_HEAD_OPACITY': '1.0',
#  'MNE_COREG_INTERACTION': 'trackball',
#  'MNE_COREG_MARK_INSIDE': 'false',
#  'MNE_COREG_ORIENT_TO_SURFACE': 'false',
#  'MNE_COREG_PREPARE_BEM': 'true',
#  'MNE_COREG_PROJECT_EEG': 'false',
#  'MNE_COREG_SCALE_BY_DISTANCE': 'false',
#  'MNE_COREG_SCALE_LABELS': 'true',
#  'MNE_COREG_SCENE_SCALE': '0.16',
#  'MNE_COREG_SUBJECTS_DIR': '/home/zcc/documents/freesurfer/subjects',
#  'MNE_COREG_WINDOW_HEIGHT': '798',
#  'MNE_COREG_WINDOW_WIDTH': '1148',
#  'MNE_DATASETS_SAMPLE_PATH': '/home/zcc/mne_data',
#  'MNE_DATASETS_SPM_FACE_PATH': '/home/zcc/mne_data',
#  'MNE_USE_CUDA': 'true',
#  'SUBJECTS_DIR': '/nfs/diskstation/zccdata/freesurfer/subjects',
#  'SUBJECT_DIR': '/nfs/diskstation/zccdata/freesurfer/subjects'}

# %%
try:
    src_fsaverage = mne.read_source_spaces('fsaverage_src.fif')
except:
    src_fsaverage = mne.setup_source_space('fsaverage', spacing='oct6', n_jobs=40)
    mne.write_source_spaces('src_fsaverage_src.fif', src)
src_fsaverage
# Out:
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
# <SourceSpaces: [<surface (lh), n_vertices=163842, n_used=4098>, <surface (rh), n_vertices=163842, n_used=4098>] MRI (surface RAS) coords, subject 'fsaverage'>

# %%
epochs
# Out:
# <EpochsFIF  |   497 events (all good), -0.2 - 1.2 sec, baseline [-0.2, 0], ~145.9 MB, data loaded,
#  '1': 497>

# %%
solver.inv
# Out:
# <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>

# %%
snr = 1.0  # use lower SNR for single epochs
lambda2 = 1.0 / snr ** 2
method = "dSPM"  # use dSPM method (could also be MNE or sLORETA)
inverse_operator = solver.inv
stcs = mne.minimum_norm.apply_inverse_epochs(epochs,
                                             inverse_operator,
                                             lambda2,
                                             method,
                                             pick_ori="normal",
                                             return_generator=True)
src = inverse_operator['src']

_labels = [e[1] for e in labels.items() if not e[0].startswith('unknown')]

label_ts = mne.extract_label_time_course(stcs, _labels, src, mode='mean_flip',
                                         return_generator=True)
# Out:
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 1
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Picked 272 channels from the data
# Computing inverse...
#     Eigenleads need to be weighted ...
# Processing epoch : 1 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 2 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 3 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 4 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 5 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 6 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 7 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 8 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 9 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 10 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 11 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 12 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 13 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 14 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 15 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 16 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 17 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 18 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 19 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 20 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 21 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 22 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 23 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 24 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 25 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 26 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 27 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 28 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 29 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 30 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 31 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 32 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 33 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 34 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 35 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 36 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 37 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 38 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 39 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 40 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 41 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 42 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 43 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 44 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 45 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 46 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 47 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 48 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 49 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 50 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 51 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 52 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 53 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 54 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 55 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 56 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 57 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 58 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 59 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 60 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 61 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 62 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 63 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 64 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 65 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 66 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 67 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 68 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 69 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 70 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 71 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 72 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 73 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 74 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 75 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 76 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 77 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 78 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 79 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 80 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 81 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 82 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 83 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 84 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 85 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 86 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 87 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 88 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 89 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 90 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 91 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 92 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 93 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 94 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 95 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 96 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 97 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 98 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 99 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 100 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 101 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 102 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 103 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 104 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 105 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 106 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 107 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 108 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 109 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 110 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 111 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 112 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 113 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 114 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 115 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 116 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 117 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 118 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 119 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 120 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 121 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 122 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 123 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 124 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 125 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 126 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 127 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 128 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 129 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 130 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 131 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 132 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 133 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 134 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 135 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 136 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 137 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 138 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 139 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 140 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 141 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 142 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 143 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 144 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 145 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 146 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 147 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 148 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 149 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 150 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 151 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 152 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 153 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 154 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 155 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 156 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 157 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 158 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 159 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 160 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 161 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 162 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 163 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 164 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 165 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 166 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 167 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 168 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 169 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 170 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 171 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 172 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 173 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 174 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 175 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 176 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 177 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 178 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 179 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 180 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 181 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 182 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 183 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 184 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 185 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 186 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 187 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 188 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 189 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 190 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 191 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 192 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 193 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 194 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 195 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 196 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 197 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 198 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 199 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 200 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 201 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 202 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 203 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 204 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 205 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 206 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 207 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 208 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 209 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 210 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 211 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 212 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 213 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 214 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 215 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 216 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 217 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 218 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 219 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 220 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 221 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 222 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 223 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 224 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 225 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 226 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 227 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 228 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 229 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 230 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 231 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 232 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 233 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 234 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 235 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 236 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 237 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 238 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 239 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 240 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 241 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 242 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 243 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 244 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 245 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 246 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 247 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 248 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 249 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 250 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 251 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 252 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 253 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 254 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 255 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 256 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 257 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 258 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 259 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 260 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 261 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 262 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 263 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 264 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 265 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 266 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 267 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 268 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 269 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 270 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 271 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 272 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 273 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 274 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 275 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 276 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 277 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 278 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 279 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 280 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 281 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 282 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 283 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 284 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 285 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 286 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 287 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 288 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 289 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 290 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 291 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 292 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 293 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 294 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 295 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 296 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 297 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 298 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 299 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 300 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 301 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 302 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 303 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 304 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 305 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 306 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 307 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 308 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 309 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 310 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 311 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 312 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 313 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 314 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 315 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 316 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 317 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 318 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 319 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 320 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 321 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 322 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 323 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 324 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 325 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 326 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 327 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 328 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 329 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 330 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 331 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 332 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 333 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 334 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 335 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 336 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 337 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 338 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 339 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 340 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 341 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 342 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 343 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 344 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 345 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 346 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 347 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 348 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 349 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 350 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 351 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 352 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 353 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 354 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 355 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 356 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 357 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 358 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 359 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 360 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 361 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 362 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 363 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 364 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 365 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 366 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 367 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 368 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 369 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 370 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 371 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 372 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 373 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 374 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 375 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 376 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 377 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 378 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 379 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 380 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 381 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 382 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 383 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 384 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 385 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 386 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 387 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 388 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 389 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 390 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 391 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 392 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 393 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 394 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 395 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 396 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 397 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 398 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 399 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 400 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 401 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 402 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 403 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 404 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 405 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 406 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 407 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 408 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 409 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 410 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 411 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 412 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 413 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 414 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 415 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 416 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 417 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 418 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 419 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 420 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 421 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 422 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 423 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 424 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 425 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 426 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 427 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 428 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 429 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 430 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 431 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 432 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 433 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 434 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 435 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 436 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 437 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 438 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 439 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 440 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 441 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 442 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 443 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 444 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 445 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 446 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 447 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 448 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 449 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 450 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 451 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 452 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 453 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 454 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 455 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 456 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 457 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 458 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 459 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 460 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 461 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 462 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 463 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 464 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 465 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 466 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 467 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 468 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 469 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 470 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 471 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 472 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 473 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 474 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 475 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 476 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 477 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 478 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 479 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 480 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 481 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 482 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 483 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 484 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 485 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 486 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 487 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 488 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 489 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 490 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 491 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 492 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 493 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 494 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 495 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 496 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# Processing epoch : 497 / 497
# Extracting time courses for 92 labels (mode: mean_flip)
# [done]

# %%
label_ts
# Out:
# (92, 141)

# %%
sfreq = 100
fmin = 0.1
fmax = 20.0
con, freqs, times, n_epochs, n_tapers = mne.connectivity.spectral_connectivity(
    label_ts, method='wpli2_debiased', mode='multitaper', sfreq=sfreq,
    fmin=fmin, fmax=fmax, mt_adaptive=True, n_jobs=32)
# Out:
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 4186 connections
#     using t=0.000s..1.400s for estimation (141 points)
#     frequencies: 0.7Hz..19.9Hz (28 points)
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epochs 1..32
# <ipython-input-95-f095bf8c4bdd>:6: RuntimeWarning: fmin=0.100 Hz corresponds to 0.141 < 5 cycles based on the epoch length 1.410 sec, need at least 50.000 sec epochs or fmin=3.546. Spectrum estimate will be unreliable.
#   fmin=fmin, fmax=fmax, mt_adaptive=True, n_jobs=32)
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    4.1s remaining:   12.2s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    4.5s remaining:    5.1s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    4.6s remaining:    2.1s
#     computing connectivity for epochs 33..64
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    4.7s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    4.8s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 65..96
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    0.9s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 97..128
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.4s remaining:    1.2s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
#     computing connectivity for epochs 129..160
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.4s remaining:    1.2s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 161..192
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    0.9s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.4s
#     computing connectivity for epochs 193..224
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 225..256
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 257..288
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 289..320
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.8s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.5s remaining:    0.1s
#     computing connectivity for epochs 321..352
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.6s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    0.8s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.4s remaining:    0.2s
#     computing connectivity for epochs 353..384
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.5s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.6s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.4s remaining:    1.3s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.5s remaining:    0.6s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.6s remaining:    0.3s
#     computing connectivity for epochs 385..416
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    0.9s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
#     computing connectivity for epochs 417..448
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.7s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.5s remaining:    0.1s
#     computing connectivity for epochs 449..480
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.6s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   8 out of  32 | elapsed:    0.4s remaining:    1.2s
# [Parallel(n_jobs=32)]: Done  15 out of  32 | elapsed:    0.5s remaining:    0.6s
# [Parallel(n_jobs=32)]: Done  22 out of  32 | elapsed:    0.6s remaining:    0.3s
#     computing connectivity for epochs 481..497
# [Parallel(n_jobs=32)]: Done  29 out of  32 | elapsed:    0.7s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  32 out of  32 | elapsed:    0.9s finished
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=32)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=32)]: Done   2 out of  17 | elapsed:    0.2s remaining:    1.5s
# [Parallel(n_jobs=32)]: Done   6 out of  17 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=32)]: Done  10 out of  17 | elapsed:    0.4s remaining:    0.3s
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# [Parallel(n_jobs=32)]: Done  14 out of  17 | elapsed:    0.5s remaining:    0.1s
# [Parallel(n_jobs=32)]: Done  17 out of  17 | elapsed:    0.5s finished

# %%
con.shape, freqs
# Out:
# ((92, 92, 28),
#  array([ 0.70921986,  1.41843972,  2.12765957,  2.83687943,  3.54609929,
#          4.25531915,  4.96453901,  5.67375887,  6.38297872,  7.09219858,
#          7.80141844,  8.5106383 ,  9.21985816,  9.92907801, 10.63829787,
#         11.34751773, 12.05673759, 12.76595745, 13.4751773 , 14.18439716,
#         14.89361702, 15.60283688, 16.31205674, 17.0212766 , 17.73049645,
#         18.43971631, 19.14893617, 19.85815603]))

# %%
# First, we reorder the labels based on their location in the left hemi
label_names = [label.name for label in _labels]
label_colors = [label.color for label in _labels]

lh_labels = [name for name in label_names if name.endswith('lh')]

# Get the y-location of the label
label_ypos = list()
for name in lh_labels:
    idx = label_names.index(name)
    ypos = np.mean(_labels[idx].pos[:, 1])
    label_ypos.append(ypos)

# Reorder the labels based on their location
lh_labels = [label for (yp, label) in sorted(zip(label_ypos, lh_labels))]

# For the right hemi
rh_labels = [label[:-2] + 'rh' for label in lh_labels]

# Save the plot order and create a circular layout
node_order = list()
node_order.extend(lh_labels[::-1])  # reverse the order
node_order.extend(rh_labels)
       
node_angles = mne.viz.circular_layout(label_names, node_order, start_pos=90,
                              group_boundaries=[0, len(label_names) / 2])

for j, name in enumerate(label_names):
    if name not in select_labels:
#         label_names[j] = '-'
        pass
        
# Plot the graph using node colors from the FreeSurfer parcellation. We only
# show the 300 strongest connections.
# fig, axes = plt.subplots(3, 3, figsize=(18, 18))
for j, freq in enumerate(freqs[::3]):
    mne.viz.plot_connectivity_circle(con[:, :, j],
                                     label_names,
                                     n_lines=10,
                                     node_angles=node_angles,
                                     node_colors=label_colors,
                                     title=f'Freq - {freq:0.4f} Hz',
                                    )
#                                      fig=fig,
#                                      subplot=(3, 3, j+1))
# Out:
# /home/zcc/anaconda3/lib/python3.7/site-packages/mne/viz/circle.py:352: RuntimeWarning: invalid value encountered in true_divide
#   con_val_scaled = (con - vmin) / vrange

# %%
# %%
# DO NOT RUN THIS UNLESS YOU WANT TO RECOMPUTE STC
stcs = dict()
stcs_baseline = dict()

spacing = [s['vertno'] for s in src_fsaverage]

for idx in range(1, 11):
    running_name = f'MEG_S{idx:02d}'
    band_name = 'U07'

    raw = mne.io.read_raw_fif(os.path.join(
        '/home/zcc/RSVP_dataset/processed_data',
        f'{running_name}/block_03_raw.fif'))
    
    _epochs = mne.read_epochs(os.path.join(
        '/home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3',
        f'{running_name}-0-train-epo.fif'))
    epochs = _epochs['1']
    epochs_baseline = _epochs['2']
    
    solver = Inverse_Solver(running_name=running_name)
    solver.pipeline(epochs=epochs,
                    raw_info=raw.info)
    
    stc, stc_fsaverage = solver.estimate(obj=epochs.average(), spacing=spacing)
    stc, stc_fsaverage_baseline = solver.estimate(obj=epochs_baseline.average(), spacing=spacing)
    
    stcs[running_name] = stc_fsaverage
    stcs_baseline[running_name] = stc_fsaverage_baseline
    
display(stcs)
display(stcs_baseline)

data = stc_fsaverage.data * 0
for running_name in stcs:
    data += stcs[running_name].data
stc_fsaverage.data = data / len(stcs)

data = stc_fsaverage_baseline.data * 0
for running_name in stcs_baseline:
    data += stcs_baseline[running_name].data
stc_fsaverage_baseline.data = data / len(stcs)

stc_fsaverage.save(os.path.join('fif_files', 'stc_fsaverage'))
stc_fsaverage_baseline.save(os.path.join('fif_files', 'stc_fsaverage_baseline'))
# Out:
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S01/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 431999 =      0.000 ...   359.999 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S01-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 10157 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S01
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S01/RSVP_MRI_S01-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S01-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S01-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 391
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  95.1% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S01, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 2375
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.4% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S01, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S02/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 431999 =      0.000 ...   359.999 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S02-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 9777 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S02
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S02/RSVP_MRI_S02-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S02-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S02-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 379
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  91.4% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S02, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 2262
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.7% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S02, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S03/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 353999 =      0.000 ...   294.999 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S03-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 10763 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S03
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S03/RSVP_MRI_S03-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S03-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S03-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 416
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  95.5% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S03, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 2612
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  89.4% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S03, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S04/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 369647 =      0.000 ...   308.039 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S04-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 12851 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S04
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S04/RSVP_MRI_S04-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S04-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S04-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 492
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.6% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S04, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3185
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.8% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S04, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S05/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 281327 =      0.000 ...   234.439 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S05-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 12839 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S05
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S05/RSVP_MRI_S05-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S05-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S05-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 498
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  93.2% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S05, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3184
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  85.7% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S05, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S06/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 277391 =      0.000 ...   231.159 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S06-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 12997 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S06
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S06/RSVP_MRI_S06-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S06-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S06-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 502
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  93.8% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S06, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3230
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  94.2% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S06, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S07/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 280127 =      0.000 ...   233.439 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S07-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 13005 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S07
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S07/RSVP_MRI_S07-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S07-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S07-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 500
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  93.3% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S07, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3262
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  94.9% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S07, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S08/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 279551 =      0.000 ...   232.959 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S08-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S08-0-train-epo-1.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 14290 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S08
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S08/RSVP_MRI_S08-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S08-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S08-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 552
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  92.4% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S08, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3543
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  94.5% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S08, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S09/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 284063 =      0.000 ...   236.719 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S09-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 11878 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S09
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S09/RSVP_MRI_S09-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S09-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S09-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 462
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  97.0% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S09, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3005
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  96.4% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S09, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Opening raw data file /home/zcc/RSVP_dataset/processed_data/MEG_S10/block_03_raw.fif...
#     Read 5 compensation matrices
#     Range : 0 ... 316895 =      0.000 ...   264.079 secs
# Ready.
# Current compensation grade : 3
# Reading /home/zcc/Documents/zcc_meg_toolbox/v2.0/mvpa_new/MVPA_data_xdawn_v3/MEG_S10-0-train-epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1200.00 ms
#         0 CTF compensation matrices available
# 12768 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Inversing on RSVP_MRI_S10
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     3 BEM surfaces found
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     Reading a surface...
# [done]
#     3 BEM surfaces read
# Loading surfaces...
# Three-layer model surfaces loaded.
#
# Loading the solution matrix...
#
# Loaded linear_collocation BEM solution from /home/zcc/RSVP_dataset/processed_data/MEG_S10/RSVP_MRI_S10-bem-sol.fif
# Reading inverse operator decomposition from /home/zcc/RSVP_dataset/memory/RSVP_MRI_S10-inv.fif...
#     Reading inverse operator info...
#     [done]
#     Reading inverse operator decomposition...
#     [done]
#     272 x 272 full covariance (kind = 1) found.
#     Noise covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 2) found.
#     Source covariance matrix read.
#     24588 x 24588 diagonal covariance (kind = 6) found.
#     Orientation priors read.
#     24588 x 24588 diagonal covariance (kind = 5) found.
#     Depth priors read.
#     Did not find the desired covariance matrix (kind = 3)
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     Reading a source space...
#     Computing patch statistics...
#     Patch information added...
#     Distance information added...
#     [done]
#     2 source spaces read
#     Source spaces transformed to the inverse solution coordinate frame
# Inverse operator is recalled: <InverseOperator | MEG channels: 272 | EEG channels: 0 | Source space: surface with 8196 sources | Source orientation: Free>
# Write inverse operator decomposition in /home/zcc/RSVP_dataset/memory/RSVP_MRI_S10-inv.fif...
#     Write a source space...
#     [done]
#     Write a source space...
#     [done]
#     2 source spaces written
#     Writing inverse operator info...
#     Writing noise covariance matrix.
#     Writing source covariance matrix.
#     Writing orientation priors.
#     [done]
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 497
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "1"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  94.7% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S10, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 3182
#     Created the regularized inverter
#     The projection vectors do not apply to these channels.
#     Created the whitener using a noise covariance matrix with rank 6 (266 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Applying inverse operator to "2"...
#     Picked 272 channels from the data
#     Computing inverse...
#     Eigenleads need to be weighted ...
#     Computing residual...
#     Explained  91.2% variance
#     Combining the current components...
#     dSPM...
# [done]
# Estimated stc: <SourceEstimate  |  8196 vertices, subject : RSVP_MRI_S10, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# Estimated morphed stc: <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>
# {'MEG_S01': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S02': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S03': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S04': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S05': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S06': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S07': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S08': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S09': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S10': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>}
# {'MEG_S01': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S02': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S03': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S04': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S05': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S06': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S07': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S08': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S09': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>,
#  'MEG_S10': <SourceEstimate  |  8196 vertices, subject : fsaverage, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>}
# Writing STC to disk...
# [done]
# Writing STC to disk...
# [done]

# %%
# %%
mne.viz.set_3d_backend('pyvista')

label_list_aparc = mne.read_labels_from_annot('fsaverage', 'aparc', 'both')
label_list_visuotopic = mne.read_labels_from_annot('fsaverage', 'PALS_B12_Visuotopic', 'both')

display(label_list_aparc)
display(label_list_visuotopic)

labels = dict()

for j, label in enumerate(label_list_visuotopic):
    if label.name.startswith('Visuotopic'):
        labels[label.name] = label
        
ROIs = ['fusiform',
        'temporal',
       ]
for j, label in enumerate(label_list_aparc):
    labels[label.name] = label
# Out:
# Using pyvista 3d backend.
#
# Reading labels from parcellation...
#    read 35 labels from /nfs/diskstation/zccdata/freesurfer/subjects/fsaverage/label/lh.aparc.annot
#    read 34 labels from /nfs/diskstation/zccdata/freesurfer/subjects/fsaverage/label/rh.aparc.annot
# Reading labels from parcellation...
#    read 16 labels from /nfs/diskstation/zccdata/freesurfer/subjects/fsaverage/label/lh.PALS_B12_Visuotopic.annot
#    read 27 labels from /nfs/diskstation/zccdata/freesurfer/subjects/fsaverage/label/rh.PALS_B12_Visuotopic.annot
# [<Label  |  fsaverage, 'bankssts-lh', lh : 2137 vertices>,
#  <Label  |  fsaverage, 'bankssts-rh', rh : 2196 vertices>,
#  <Label  |  fsaverage, 'caudalanteriorcingulate-lh', lh : 1439 vertices>,
#  <Label  |  fsaverage, 'caudalanteriorcingulate-rh', rh : 1608 vertices>,
#  <Label  |  fsaverage, 'caudalmiddlefrontal-lh', lh : 3736 vertices>,
#  <Label  |  fsaverage, 'caudalmiddlefrontal-rh', rh : 3494 vertices>,
#  <Label  |  fsaverage, 'cuneus-lh', lh : 1630 vertices>,
#  <Label  |  fsaverage, 'cuneus-rh', rh : 1638 vertices>,
#  <Label  |  fsaverage, 'entorhinal-lh', lh : 1102 vertices>,
#  <Label  |  fsaverage, 'entorhinal-rh', rh : 902 vertices>,
#  <Label  |  fsaverage, 'frontalpole-lh', lh : 272 vertices>,
#  <Label  |  fsaverage, 'frontalpole-rh', rh : 369 vertices>,
#  <Label  |  fsaverage, 'fusiform-lh', lh : 4714 vertices>,
#  <Label  |  fsaverage, 'fusiform-rh', rh : 4661 vertices>,
#  <Label  |  fsaverage, 'inferiorparietal-lh', lh : 7871 vertices>,
#  <Label  |  fsaverage, 'inferiorparietal-rh', rh : 9676 vertices>,
#  <Label  |  fsaverage, 'inferiortemporal-lh', lh : 4415 vertices>,
#  <Label  |  fsaverage, 'inferiortemporal-rh', rh : 4198 vertices>,
#  <Label  |  fsaverage, 'insula-lh', lh : 5229 vertices>,
#  <Label  |  fsaverage, 'insula-rh', rh : 5090 vertices>,
#  <Label  |  fsaverage, 'isthmuscingulate-lh', lh : 2531 vertices>,
#  <Label  |  fsaverage, 'isthmuscingulate-rh', rh : 2388 vertices>,
#  <Label  |  fsaverage, 'lateraloccipital-lh', lh : 6379 vertices>,
#  <Label  |  fsaverage, 'lateraloccipital-rh', rh : 5963 vertices>,
#  <Label  |  fsaverage, 'lateralorbitofrontal-lh', lh : 4188 vertices>,
#  <Label  |  fsaverage, 'lateralorbitofrontal-rh', rh : 4354 vertices>,
#  <Label  |  fsaverage, 'lingual-lh', lh : 4205 vertices>,
#  <Label  |  fsaverage, 'lingual-rh', rh : 3894 vertices>,
#  <Label  |  fsaverage, 'medialorbitofrontal-lh', lh : 2653 vertices>,
#  <Label  |  fsaverage, 'medialorbitofrontal-rh', rh : 2801 vertices>,
#  <Label  |  fsaverage, 'middletemporal-lh', lh : 4452 vertices>,
#  <Label  |  fsaverage, 'middletemporal-rh', rh : 5057 vertices>,
#  <Label  |  fsaverage, 'paracentral-lh', lh : 3294 vertices>,
#  <Label  |  fsaverage, 'paracentral-rh', rh : 3831 vertices>,
#  <Label  |  fsaverage, 'parahippocampal-lh', lh : 1838 vertices>,
#  <Label  |  fsaverage, 'parahippocampal-rh', rh : 1742 vertices>,
#  <Label  |  fsaverage, 'parsopercularis-lh', lh : 3119 vertices>,
#  <Label  |  fsaverage, 'parsopercularis-rh', rh : 2472 vertices>,
#  <Label  |  fsaverage, 'parsorbitalis-lh', lh : 956 vertices>,
#  <Label  |  fsaverage, 'parsorbitalis-rh', rh : 946 vertices>,
#  <Label  |  fsaverage, 'parstriangularis-lh', lh : 2046 vertices>,
#  <Label  |  fsaverage, 'parstriangularis-rh', rh : 2380 vertices>,
#  <Label  |  fsaverage, 'pericalcarine-lh', lh : 1912 vertices>,
#  <Label  |  fsaverage, 'pericalcarine-rh', rh : 1823 vertices>,
#  <Label  |  fsaverage, 'postcentral-lh', lh : 9519 vertices>,
#  <Label  |  fsaverage, 'postcentral-rh', rh : 9138 vertices>,
#  <Label  |  fsaverage, 'posteriorcingulate-lh', lh : 3266 vertices>,
#  <Label  |  fsaverage, 'posteriorcingulate-rh', rh : 2994 vertices>,
#  <Label  |  fsaverage, 'precentral-lh', lh : 10740 vertices>,
#  <Label  |  fsaverage, 'precentral-rh', rh : 10705 vertices>,
#  <Label  |  fsaverage, 'precuneus-lh', lh : 7308 vertices>,
#  <Label  |  fsaverage, 'precuneus-rh', rh : 7975 vertices>,
#  <Label  |  fsaverage, 'rostralanteriorcingulate-lh', lh : 1350 vertices>,
#  <Label  |  fsaverage, 'rostralanteriorcingulate-rh', rh : 1051 vertices>,
#  <Label  |  fsaverage, 'rostralmiddlefrontal-lh', lh : 7243 vertices>,
#  <Label  |  fsaverage, 'rostralmiddlefrontal-rh', rh : 7864 vertices>,
#  <Label  |  fsaverage, 'superiorfrontal-lh', lh : 12179 vertices>,
#  <Label  |  fsaverage, 'superiorfrontal-rh', rh : 11878 vertices>,
#  <Label  |  fsaverage, 'superiorparietal-lh', lh : 10456 vertices>,
#  <Label  |  fsaverage, 'superiorparietal-rh', rh : 10222 vertices>,
#  <Label  |  fsaverage, 'superiortemporal-lh', lh : 7271 vertices>,
#  <Label  |  fsaverage, 'superiortemporal-rh', rh : 6868 vertices>,
#  <Label  |  fsaverage, 'supramarginal-lh', lh : 8600 vertices>,
#  <Label  |  fsaverage, 'supramarginal-rh', rh : 8150 vertices>,
#  <Label  |  fsaverage, 'temporalpole-lh', lh : 839 vertices>,
#  <Label  |  fsaverage, 'temporalpole-rh', rh : 817 vertices>,
#  <Label  |  fsaverage, 'transversetemporal-lh', lh : 1064 vertices>,
#  <Label  |  fsaverage, 'transversetemporal-rh', rh : 781 vertices>,
#  <Label  |  fsaverage, 'unknown-lh', lh : 2 vertices>]
# [<Label  |  fsaverage, '???-lh', lh : 116427 vertices>,
#  <Label  |  fsaverage, '???-rh', rh : 117864 vertices>,
#  <Label  |  fsaverage, '????-rh', rh : 117864 vertices>,
#  <Label  |  fsaverage, '???????-rh', rh : 117864 vertices>,
#  <Label  |  fsaverage, 'AUDITORY-lh', lh : 930 vertices>,
#  <Label  |  fsaverage, 'AUDITORY-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'GYRUS-rh', rh : 117864 vertices>,
#  <Label  |  fsaverage, 'LANDMARK.MT-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'LANDMARK.V2d-rh', rh : 1867 vertices>,
#  <Label  |  fsaverage, 'LANDMARK.V2v-rh', rh : 1867 vertices>,
#  <Label  |  fsaverage, 'MEDIAL.WALL-lh', lh : 11608 vertices>,
#  <Label  |  fsaverage, 'MEDIAL.WALL-rh', rh : 11312 vertices>,
#  <Label  |  fsaverage, 'NonVisuotopic-lh', lh : 22715 vertices>,
#  <Label  |  fsaverage, 'NonVisuotopic-rh', rh : 21697 vertices>,
#  <Label  |  fsaverage, 'SUL.HF-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'SUL.ISS-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'Thresh_Normal_deeper_t_3-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.LO-lh', lh : 1015 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.LO-rh', rh : 1021 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.MTplus-lh', lh : 930 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.MTplus-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V1d-lh', lh : 4063 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V1d-rh', rh : 3506 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V1v-lh', lh : 4063 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V1v-rh', rh : 3506 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V2d-lh', lh : 1888 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V2d-rh', rh : 1867 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V2v-lh', lh : 1888 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V2v-rh', rh : 1867 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V3-lh', lh : 575 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V3-rh', rh : 774 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V3A-lh', lh : 737 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V3A-rh', rh : 882 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V4v-lh', lh : 1030 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V4v-rh', rh : 860 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V7-lh', lh : 796 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V7-rh', rh : 621 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V8-lh', lh : 881 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.V8-rh', rh : 1246 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.VP-lh', lh : 1177 vertices>,
#  <Label  |  fsaverage, 'Visuotopic.VP-rh', rh : 1237 vertices>,
#  <Label  |  fsaverage, 'plus_cluster_area_574.765_nodes_715-rh', rh : 955 vertices>,
#  <Label  |  fsaverage, 'plus_cluster_area_997.997_nodes_907-rh', rh : 955 vertices>]

# %%
# DO NOT RUN THIS,
# IT IS VERY SLOW
if False:
    brain = Brain(subject_id='fsaverage',
                  hemi='split',
                  surf='inflated',
                  cortex='low_contrast',
                  background='white',
                  size=(800, 600))
    # brain.add_annotation('aparc')
    # brain.add_annotation(label_name)
    for name in labels:
        print(name)
        brain.add_label(labels[name], borders=True)
    print('Done.')

    mlab.show()

# %%
stc_fsaverage = mne.read_source_estimate(os.path.join('fif_files', 'stc_fsaverage'))
stc_fsaverage_baseline = mne.read_source_estimate(os.path.join('fif_files', 'stc_fsaverage_baseline'))

stc = stc_fsaverage_baseline
stc.data = stc_fsaverage.data - stc_fsaverage_baseline.data
stc
# Out:
# <SourceEstimate  |  8196 vertices, tmin : -200.0 (ms), tmax : 1200.0000000000002 (ms), tstep : 10.0 (ms), data shape : (8196, 141)>

# %%
alldata = sorted(stc.data.ravel(), reverse=True)
n = len(alldata)
LIMS = [alldata[int(n * r)] for r in [0.05, 0.01, 0.005, 0]]
LIMS
# Out:
# [27.154327, 33.061977, 35.144455, 47.206467]

# %%
lims = LIMS[1:]

from sklearn.manifold import TSNE

data = stc.data
large_data = data[np.max(data, axis=1) > lims[0]]
large_data.shape, data.shape

tsne = TSNE(n_components=2, n_jobs=40)
proj_data = tsne.fit_transform(data.transpose())

plt.style.use('ggplot')
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

ax.scatter(proj_data[:, 0], proj_data[:, 1], range(141), alpha=0.5)
ax.plot(proj_data[:, 0], proj_data[:, 1])

idxs = []
for t in [0.0, 0.3, 0.5, 0.8]:
    idx = np.where(t == stc.times)[0][0]
    ax.text(proj_data[idx, 0]+0.2, proj_data[idx, 1]+0.2, t, fontdict=dict(size=15))
    idxs.append(idx)
    
ax.scatter(proj_data[idxs, 0], proj_data[idxs, 1], 100)
ax.set_title('TSNE')

fig.savefig('TSNE.png')

# %%
ts = mne.extract_label_time_course(stc, label_list_aparc, src_fsaverage, mode='mean_flip', allow_empty=True, return_generator=True)
ts.shape
# Out:
# Extracting time courses for 69 labels (mode: mean_flip)
# <ipython-input-17-34ad0a17b39a>:1: RuntimeWarning: source space does not contain any vertices for label unknown-lh. Assigning all-zero time series to label.
#   ts = mne.extract_label_time_course(stc, label_list_aparc, src_fsaverage, mode='mean_flip', allow_empty=True, return_generator=True)
# (69, 141)

# %%
lims = LIMS[1:]

plt.style.use('ggplot')
fig, axes = plt.subplots(1, 2, figsize=(8, 10))

times = stc.times
select_labels = dict()
for name in labels:
    label = labels[name]
    color = label.color
    try:
        stc_inlabel = stc.in_label(label)
    except ValueError:
        continue
    data = stc_inlabel.data
    data = data[np.max(data, axis=1) > lims[1]]
    if len(data) < 10:
        continue
    # print(name, color, data.shape)
    
#     sort = sorted(data.ravel(), reverse=True)
#     if sort[1000] < lims[0]:
#         continue
    
    mean_data = np.mean(data, axis=0)
    
    if name.endswith('-lh'):
        ax = axes[0]
    else:
        ax = axes[1]
        
    ax.plot(times, mean_data, c=color, label=f'{name}-{len(data)}', alpha=0.5, linewidth=3)
    
    select_labels[name] = label

for j in [0, 1]:
    axes[j].legend(loc='upper left', bbox_to_anchor=(0, -0.1))
    
axes[0].set_title('LEFT')
axes[1].set_title('RIGHT')

fig.tight_layout()
fig.savefig('WaveForm.png')

# %%
lims, initial_time = LIMS[1:], 0.3
# lims, initial_time = LIMS[:-1], 0.5
mne.viz.set_3d_backend('pyvista')
views = ['lat']
clim = dict(kind='value', lims=lims)
surfer_kwargs = dict(hemi='both',
                     clim=clim,
                     views=views,
                     initial_time=initial_time,
                     time_unit='s',
                     size=(800, 800),
                     smoothing_steps=10,
                     time_viewer=True,
                     subject='fsaverage')

# This can not be operated using VS code
brain = stc.plot(**surfer_kwargs)

for name in select_labels:
    print(name)
    brain.add_label(labels[name], borders=True)

# mlab.show()
# Out:
# Visuotopic.LO-rh
# Visuotopic.MTplus-rh
# Visuotopic.V7-rh
# Visuotopic.V8-rh
# bankssts-lh
# caudalmiddlefrontal-rh
# fusiform-lh
# fusiform-rh
# inferiorparietal-lh
# inferiorparietal-rh
# inferiortemporal-lh
# insula-lh
# isthmuscingulate-lh
# isthmuscingulate-rh
# lateraloccipital-rh
# lingual-rh
# middletemporal-lh
# paracentral-lh
# paracentral-rh
# parstriangularis-lh
# postcentral-rh
# posteriorcingulate-lh
# posteriorcingulate-rh
# precuneus-lh
# precuneus-rh
# rostralmiddlefrontal-lh
# superiorparietal-lh
# superiorparietal-rh
# superiortemporal-lh
# supramarginal-lh

# %%
lims = LIMS[:3]
mne.viz.set_3d_backend('pyvista')
views = ['lat', 'med', 'cau', 'dor', 'ven']
clim = dict(kind='value', lims=lims)
surfer_kwargs = dict(hemi='both',
                     clim=clim,
                     views=views,
                     initial_time=0.5,
                     time_unit='s',
                     size=(800, 800),
                     smoothing_steps=10,
                     time_viewer=False,
                     subject='fsaverage')

# This can not be operated using VS code
brain = stc.plot(**surfer_kwargs)

# for name in select_labels:
#     print(name)
#     brain.add_label(labels[name], borders=True)

# mlab.show()
